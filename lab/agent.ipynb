# %%
from agent.rl import DQN
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'autoscaling (Python 3.12.11)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
load_dotenv("../agent/.env")

# %%
algorithm = DQN()
