# %% [markdown]
# # Import

# %%
import Box2D
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %% [markdown]
# # Test Environment

# %%
environment_name = "CarRacing-v3"
# env = gym.make(environment_name, render_mode='human')

# %%
# env.reset()

# %%
# env.action_space

# %%
# env.observation_space

# %%
# env.close()

# %%
# episodes = 10
# for episode in range(1, episodes+1):
#     env.reset()
#     terminated = False
#     truncated = False
#     score = 0
    
#     while not terminated and not truncated:
#         action = env.action_space.sample()
#         n_state, reward, terminated, truncated, info = env.step(action)
#         score += reward
#     print(f"Episode: {episode}  Score {score}")
# env.close()

# %% [markdown]
# ### Train Model

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])

# %%
log_path = os.path.join("training", "logs")
# model = PPO("CnnPolicy", env, verbose=1, tensorboard_log=log_path)

# %%
# env.reset()

# %%
# env.close()

# %%
# model.learn(total_timesteps=2000000)

# %% [markdown]
# ## Save and Reload Model

# %%
ppo_path = os.path.join("training","models","PPO_CNN_4_5M_Driving_Model")
model = PPO.load(ppo_path, env)

# %%
model.learn(500000,reset_num_timesteps=False, progress_bar=True)
new_ppo_path = os.path.join("training","models","PPO_CNN_6M_Driving_Model")
model.save(new_ppo_path)

# %%
del model

# %%
model = PPO.load(ppo_path, env)

# %% [markdown]
# # Evaluate and Test

# %%
env = gym.make(environment_name, render_mode='human')

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
