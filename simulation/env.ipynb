# %%
from kubernetes import client, config
from gymnasium.spaces import Discrete

# %%
space = Discrete(11, start=-5)
print(f"start: {space.start},  n: {space.n}")
for i in range(50):
    print(f"sample: {space.sample()}")
# Out:
# start: -5,  n: 11
# sample: -2
# sample: 4
# sample: -1
# sample: 2
# sample: 2
# sample: -2
# sample: -2
# sample: 4
# sample: 5
# sample: -4
# sample: -2
# sample: -2
# sample: 0
# sample: 0
# sample: 5
# sample: -3
# sample: 3
# sample: -4
# sample: 4
# sample: 3
# sample: -2
# sample: 3
# sample: -4
# sample: 1
# sample: -3
# sample: -2
# sample: -3
# sample: -1
# sample: 2
# sample: 3
# sample: 3
# sample: 3
# sample: 3
# sample: -5
# sample: 1
# sample: -3
# sample: 1
# sample: 2
# sample: -3
# sample: 2
# sample: -4
# sample: 2
# sample: -3
# sample: 2
# sample: 2
# sample: 3
# sample: 1
# sample: 3
# sample: -2
# sample: 4

# %%
config.load_kube_config()
cluster = client.AppsV1Api()
api = client.CustomObjectsApi()

# %%
metric_data = api.list_namespaced_custom_object(
    group="metrics.k8s.io",
    version="v1beta1",
    namespace="default",
    plural="pods",
)

metric_data
# Out:
# /Users/fauzanghaza/Documents/code/autoscaling/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '100.127.139.26'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# {'kind': 'PodMetricsList',
#  'apiVersion': 'metrics.k8s.io/v1beta1',
#  'metadata': {},
#  'items': [{'metadata': {'name': 'nginx-deployment-6db5b96cc7-2jbpw',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.004s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '6679085n', 'memory': '1896Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-4q4fh',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.999s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '4432428n', 'memory': '1892Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-4znfx',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.988s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '2287096n', 'memory': '1908Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-5z2p6',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.01s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '3721785n', 'memory': '1908Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-6nx5l',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.998s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '3783771n', 'memory': '1900Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-7c6rd',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.996s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '3487730n', 'memory': '1892Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-7gvs7',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.995s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '4476892n', 'memory': '1908Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-7m9vz',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.002s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '1454406n', 'memory': '1892Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-7mq2s',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.013s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '5872443n', 'memory': '1892Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-8549n',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.001s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '771548n', 'memory': '1888Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-88hzq',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.991s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '7382496n', 'memory': '1900Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-899nq',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.993s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '4008070n', 'memory': '1896Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-8jj8h',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.003s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '5316869n', 'memory': '1900Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-8lmp6',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.01s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '5936175n', 'memory': '1892Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-8rqk4',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.998s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '756900n', 'memory': '1904Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-95c52',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.995s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '3752584n', 'memory': '1896Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-9bmrb',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.008s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '6030250n', 'memory': '1908Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-bgshl',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.003s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '5874558n', 'memory': '1900Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-bsw4z',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.001s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '2354309n', 'memory': '1924Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-c64q8',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.001s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '3012665n', 'memory': '1892Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-chs29',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.011s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '5312504n', 'memory': '1904Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-cqcrd',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.998s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '3274036n', 'memory': '1904Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-f2cb5',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.001s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '1478834n', 'memory': '1900Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-fgbgx',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.001s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '4021665n', 'memory': '1912Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-fsnwn',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '8411600n', 'memory': '1908Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-fznt5',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.008s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '5430770n', 'memory': '1900Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-g2jxq',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.003s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '2245817n', 'memory': '1904Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-gl5g7',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.998s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '4813241n', 'memory': '1888Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-gq422',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.992s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '5281216n', 'memory': '1896Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-hnks5',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.005s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '3935954n', 'memory': '1904Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-hw8kq',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.995s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '4584328n', 'memory': '1904Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-hwtpn',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.991s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '1675405n', 'memory': '1916Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-hz4sp',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.004s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '4487003n', 'memory': '1912Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-j7bnf',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.009s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '5017989n', 'memory': '1900Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-jbd2g',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.998s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '2346512n', 'memory': '1900Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-jcdkc',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.997s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '3112755n', 'memory': '1904Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-jkpx4',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.012s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '3862509n', 'memory': '1900Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-jr6nb',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '2956400n', 'memory': '1896Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-khgcj',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.014s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '6766018n', 'memory': '1900Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-ktflf',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.003s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '3074585n', 'memory': '1908Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-kxkmw',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.999s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '3676578n', 'memory': '1896Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-l6g2m',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.001s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '4346710n', 'memory': '1896Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-lkl9d',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.997s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '4791558n', 'memory': '1904Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-llbrg',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.002s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '5223703n', 'memory': '1892Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-lpqdd',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '4630866n', 'memory': '1876Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-lqm9j',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.008s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '3112806n', 'memory': '1888Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-mnrlw',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.003s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '4908818n', 'memory': '1908Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-mr7zb',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.017s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '6164613n', 'memory': '1900Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-n52hc',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '2207866n', 'memory': '1916Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-p78xl',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.994s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '2318527n', 'memory': '1892Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-qv88j',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '5163066n', 'memory': '1896Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-s6ltd',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.988s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '1451694n', 'memory': '1908Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-s6r2d',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.005s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '6219526n', 'memory': '1896Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-sn745',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.001s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '4684354n', 'memory': '1896Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-t56mj',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.009s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '1401225n', 'memory': '1908Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-tgn8l',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.997s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '6916249n', 'memory': '1908Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-tld28',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.002s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '3078056n', 'memory': '1912Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-tm5c6',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.998s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '2942058n', 'memory': '1900Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-tnbgs',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.005s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '4436054n', 'memory': '1900Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-tr9vq',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.988s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '4593341n', 'memory': '1892Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-v4zvm',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.994s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '6929905n', 'memory': '1904Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-vmj5n',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.002s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '3689441n', 'memory': '1900Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-vwsjq',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.994s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '3910497n', 'memory': '1900Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-wj2pb',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.007s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '3164856n', 'memory': '1900Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-wl9rq',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.997s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '2113222n', 'memory': '1896Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-ww2jb',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.999s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '3633508n', 'memory': '1900Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-x482c',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '4378600n', 'memory': '1904Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-x556d',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.013s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '3723972n', 'memory': '1892Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-x6spl',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.011s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '2897874n', 'memory': '1896Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-xgvbf',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.989s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '2206217n', 'memory': '1896Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-xmdqn',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.993s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '1529913n', 'memory': '1908Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-xrmml',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '14.994s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '5261971n', 'memory': '1912Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-6db5b96cc7-zvzfw',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-13T04:02:12Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '6db5b96cc7'}},
#    'timestamp': '2025-07-13T04:01:58Z',
#    'window': '15.003s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '5809904n', 'memory': '1904Ki'}}]}]}

# %%
core = client.CoreV1Api()

# %%
def parse_cpu_value(cpu_str):
    """Parse CPU value from kubernetes format to cores (float)"""
    try:
        if cpu_str.endswith("m"):
            return float(cpu_str[:-1]) / 1000
        if cpu_str.endswith("n"):
            return float(cpu_str[:-1]) / 1000000000
        if cpu_str.endswith("u"):
            return float(cpu_str[:-1]) / 1000000
        return float(cpu_str)
    except (ValueError, IndexError) as e:
        print(f"Could not parse CPU value '{cpu_str}': {e}")
        return 0.0

def parse_memory_value(memory_str):
    """Parse memory value from kubernetes format to MB (float)"""
    try:
        if memory_str.endswith("Ki"):
            return float(memory_str[:-2]) / 1024
        if memory_str.endswith("Mi"):
            return float(memory_str[:-2])
        if memory_str.endswith("Gi"):
            return float(memory_str[:-2]) * 1024
        if memory_str.endswith("Ti"):
            return float(memory_str[:-2]) * 1024 * 1024
        return float(memory_str) / (1024 * 1024)
    except (ValueError, IndexError) as e:
        print(f"Could not parse memory value '{memory_str}': {e}")
        return 0.0

# %%
def get_node_capacity():
    """Get total CPU and memory capacity across all nodes"""
    try:
        nodes = core.list_node()
        total_cpu = 0
        total_memory = 0

        for node in nodes.items:
            if getattr(node.spec, "unschedulable", False):
                print(f"Node {node.metadata.name}: SKIPPED (unschedulable)")
                continue

            taints = getattr(node.spec, 'taints', []) or []
            has_no_schedule_taint = any(
                taint.effect == 'NoSchedule' and
                taint.key == 'node-role.kubernetes.io/control-plane'
                for taint in taints
            )

            if has_no_schedule_taint:
                print(f"Node {node.metadata.name}: SKIPPED (control plane taint)")
                continue

            allocatable = node.status.allocatable
            cpu_str = allocatable.get("cpu", "0")
            memory_str = allocatable.get("memory", "0")

            cpu_cores = parse_cpu_value(cpu_str)
            memory_mb = parse_memory_value(memory_str)

            total_cpu += cpu_cores
            total_memory += memory_mb

            print(
                f"Node {node.metadata.name}: CPU={cpu_cores:.2f} cores, "
                f"Memory={memory_mb:.2f} MB"
            )

        return total_cpu, total_memory

    except Exception as e:
        print(f"Could not get node capacity: {e}")
        return 4.0, 8192.0  # Default fallback

# %%
def get_node_resource_usage(node_cpu_total, node_memory_total):
    """Get current resource usage across schedulable nodes only"""
    try:
        # Get node metrics from metrics server
        node_metrics = api.list_cluster_custom_object(
            group="metrics.k8s.io", version="v1beta1", plural="nodes"
        )

        # Get list of schedulable nodes
        nodes = core.list_node()
        schedulable_node_names = set()

        for node in nodes.items:
            if getattr(node.spec, "unschedulable", False):
                continue

            taints = getattr(node.spec, "taints", []) or []
            has_no_schedule_taint = any(
                taint.effect == "NoSchedule"
                and taint.key == "node-role.kubernetes.io/control-plane"
                for taint in taints
            )

            if not has_no_schedule_taint:
                schedulable_node_names.add(node.metadata.name)

        total_cpu_used = 0
        total_memory_used = 0

        if node_metrics and "items" in node_metrics:
            for node in node_metrics["items"]:
                node_name = node["metadata"]["name"]

                # Only include schedulable nodes
                if node_name not in schedulable_node_names:
                    print(f"Node {node_name}: SKIPPED from metrics (not schedulable)")
                    continue

                cpu_str = node["usage"]["cpu"]
                memory_str = node["usage"]["memory"]

                cpu_cores = parse_cpu_value(cpu_str)
                memory_mb = parse_memory_value(memory_str)

                total_cpu_used += cpu_cores
                total_memory_used += memory_mb

                print(
                    f"Node {node_name}: CPU usage={cpu_cores:.3f} cores, Memory usage={memory_mb:.2f} MB"
                )

        # Calculate available percentages
        cpu_available_percent = max(0, 100 - (total_cpu_used / node_cpu_total * 100))
        memory_available_percent = max(
            0, 100 - (total_memory_used / node_memory_total * 100)
        )

        print(
            f"Total usage: CPU={total_cpu_used:.3f}/{node_cpu_total:.2f} cores, Memory={total_memory_used:.2f}/{node_memory_total:.2f} MB"
        )
        print(
            f"Available: CPU={cpu_available_percent:.1f}%, Memory={memory_available_percent:.1f}%"
        )

        return cpu_available_percent, memory_available_percent

    except Exception as e:
        print(f"Could not get node resource usage: {e}")
        return 50.0, 50.0  # Default fallback values

# %%
node_cpu_total, node_memory_total = get_node_capacity()
# Out:
# Node control: SKIPPED (unschedulable)
# Node worker-1: CPU=6.00 cores, Memory=5824.61 MB
# /Users/fauzanghaza/Documents/code/autoscaling/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '100.127.139.26'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
cpu_avail, memory_avail = get_node_resource_usage(node_cpu_total, node_memory_total)
print(f"CPU Available: {cpu_avail:.2f}%, Memory Available: {memory_avail:.2f}%")
# Out:
# Node control: SKIPPED from metrics (not schedulable)
# Node worker-1: CPU usage=0.364 cores, Memory usage=3333.25 MB
# Total usage: CPU=0.364/6.00 cores, Memory=3333.25/5824.61 MB
# Available: CPU=93.9%, Memory=42.8%
# CPU Available: 93.94%, Memory Available: 42.77%
# /Users/fauzanghaza/Documents/code/autoscaling/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '100.127.139.26'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/fauzanghaza/Documents/code/autoscaling/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '100.127.139.26'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
