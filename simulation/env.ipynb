# %%
from kubernetes import client, config
from gymnasium.spaces import Discrete

# %%
space = Discrete(11, start=-5)
print(f"start: {space.start},  n: {space.n}")
for i in range(50):
    print(f"sample: {space.sample()}")
# Out:
# start: -5,  n: 11
# sample: -5
# sample: 2
# sample: 1
# sample: -2
# sample: 3
# sample: 0
# sample: -1
# sample: 5
# sample: -5
# sample: 1
# sample: -4
# sample: -3
# sample: -3
# sample: 0
# sample: -2
# sample: 2
# sample: -4
# sample: 2
# sample: -2
# sample: -5
# sample: 0
# sample: 3
# sample: 1
# sample: 3
# sample: -3
# sample: -3
# sample: -2
# sample: 1
# sample: -4
# sample: 3
# sample: -4
# sample: 1
# sample: 5
# sample: 3
# sample: 5
# sample: -1
# sample: -2
# sample: 3
# sample: 2
# sample: -4
# sample: 4
# sample: 4
# sample: -3
# sample: 3
# sample: -1
# sample: -5
# sample: 4
# sample: -5
# sample: -5
# sample: 4

# %%
config.load_kube_config()
cluster = client.AppsV1Api()
api = client.CustomObjectsApi()

# %%
metric_data = api.list_namespaced_custom_object(
    group="metrics.k8s.io",
    version="v1beta1",
    namespace="default",
    plural="pods",
)

metric_data
# Out:
# /Users/fauzanghaza/Documents/code/autoscaling/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '100.127.139.26'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# {'kind': 'PodMetricsList',
#  'apiVersion': 'metrics.k8s.io/v1beta1',
#  'metadata': {},
#  'items': [{'metadata': {'name': 'nginx-deployment-677675487b-27d77',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-12T07:09:15Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '677675487b'}},
#    'timestamp': '2025-07-12T07:09:13Z',
#    'window': '15.001s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '0', 'memory': '1852Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-677675487b-fj5cq',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-12T07:09:15Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '677675487b'}},
#    'timestamp': '2025-07-12T07:09:13Z',
#    'window': '14.996s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '0', 'memory': '1868Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-677675487b-gcc7h',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-12T07:09:15Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '677675487b'}},
#    'timestamp': '2025-07-12T07:09:13Z',
#    'window': '15.001s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '0', 'memory': '1880Ki'}}]},
#   {'metadata': {'name': 'nginx-deployment-677675487b-gp7pq',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-12T07:09:15Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '677675487b'}},
#    'timestamp': '2025-07-12T07:09:13Z',
#    'window': '15s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '0', 'memory': '1864Ki'}}]}]}

# %%
metric_data
# Out:
# {'kind': 'PodMetricsList',
#  'apiVersion': 'metrics.k8s.io/v1beta1',
#  'metadata': {},
#  'items': [{'metadata': {'name': 'nginx-deployment-677675487b-fj5cq',
#     'namespace': 'default',
#     'creationTimestamp': '2025-07-12T07:07:30Z',
#     'labels': {'app': 'nginx',
#      'name': 'nginx-deployment',
#      'pod-template-hash': '677675487b'}},
#    'timestamp': '2025-07-12T07:07:28Z',
#    'window': '15.007s',
#    'containers': [{'name': 'nginx',
#      'usage': {'cpu': '0', 'memory': '1868Ki'}}]}]}
